# %% [markdown]
# # Measures of Dispersion
#
# Dispersion of data used to understands the distribution of data. It helps to understand the variation of data and provides a piece of information about the distribution data. Variance, Standard Deviation,Range and IQR are the methods used to understand the distribution data.
#
# Dispersion of data helps to identify outliers in a given dataset.
#
# Measures of Dispersion are also called as **Measures of Variablity.**
#
# Following are some of the measures of variability that offers to differentiate between datasets:
# 1. Variance
# 2. Standard Deviation
# 3. Range
# 4. Interquartile range

# %% [markdown]
# # Variance
#
# The variance is a numerical measure of how the data values is dispersed around the mean. Mathematically, it is defined as the average of squared differences from the mean value.
#
# To calculate the variance follows these steps:
# 1. Find out the mean
# 2. Then for each number subtract the mean and square the result
# 3. The worked out the average of those squared difference
#
# Formula:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ex: Find the variance of the numbers 3,8,6,10,12,9,11,10,12,7.

# %%
import numpy as np
import pandas as pd
import statistics as st
data=np.array([3,8,6,10,12,9,11,10,12,7])
var = st.variance(data)
print("The variance is: ",var)
# Out:
# The variance is:  8

# %% [markdown]
# # Standard Deviation
#
# Standard Deviation is a measure of spread in statistics. It is used to quantify the measure of spread. Variation of a set of data values. It is very much similar to variance, gives the measure of deviation whereas variation provide the squared value.
#
# Standard Deviation measures the spreadness of data values with respect to mean and mathematically, is calculated as square root of variance.
#
# Formula:
#
# ![image.png](attachment:image.png)
#
# Eg: During a survey 6 students were asked how many hours per day they study on an average? Their answers were as follows 2,6,5,3,2,3. Evaluate the Standard Deviation.

# %%
import numpy as np
import pandas as pd
import statistics as st
data=np.array([2,6,5,3,2,3])
std = st.stdev(data)
print("The Standard Deviation is: ",std)
# Out:
# The Standard Deviation is:  1.4142135623730951

# %% [markdown]
# # Range
#
# The range can measure by subtracting the lowest value from the largest value. The wide range indicates high variability, and the small range specifies low variability in the distribution.
#
# To calculate a range, prepare all the values in ascending order, then subtract the lowest value from the highest value.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Eg: Calculate the range for the following table.
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
x=np.array([37,33,19,25,28])
print("The range is: ",max(x)-min(x))
# Out:
# The range is:  18

# %% [markdown]
# # Mid Range
#
# The mid range of a set of statistical data values is the arithmetic mean of the maximum and minimum value in dataset.
#
# ![image.png](attachment:image.png)
#
# Eg: Find the midrange of this data: 4,6,9,3,7

# %% [markdown]
# # Measures of Central Tendency
#
# A measure of central tendency is a summary statistic that represents the center point or typical value of a dataset. These measures indicate where most values in a distribution fall and are also referred to as the central location of a distribution.
#
# # Types of Central Tendency
# There are three main types of measures of central tendency which sare as follows
# - Mean
# - Median
# - Mode
#
# Mean, Median, Mode are different measures of center in a numerical data set. They each try to summarize a dataset with a single number to represent a "typical" data point from the data set.
#
# Let’s begin with the visual representations to better interpret the concepts:
#
# *Dataset used — Heights of seven Bodybuilders(Assumed Discrete Series)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Mean
#
# Mean is defined by the "average" number found by adding all data points divided by the total number of datapoints.
#
# The arithmetic mean is sum of all data points divided by the total number of data points
#
# ![image.png](attachment:image.png)
#
# Manual Calculation of mean
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Let's calculate mean of the above data manually for clear understanding

# %%
# python mean implementation using above data
import numpy as np
import pandas as pd

data = np.array([150,160,160,170,155,180,175])
mean = data.mean()
print("The mean of the data point is ",mean)
# Out:
# The mean of the data point is  164.28571428571428

# %% [markdown]
# ![image.png](attachment:image.png)
#
# So we can say thta the mean height of the body builders are approx 164.28 cm

# %%
# solving mean with an outlier data point
import numpy as np
import pandas as pd

data = np.array([150,160,160,170,155,180,175,500])
mean = data.mean()
print("The mean of the data point is ",mean)
# Out:
# The mean of the data point is  206.25

# %% [markdown]
# **`Explaination`**:As you can see because of one outlier value 500 your mean get corrupted by a high margin from 164.28 to 206.25. So, mean is **outlier prone central tendency measure.**

# %% [markdown]
# # Mode
#
# This is the easiest one to calculate, just determine the frequency of occurrence of each data point in the data, and the one with the highest frequency is the mode of the data. This measure can also be used when the data is non-numerical.
#
# The mode is the most commonly occuring data points in a dataset. The mode is useful when there are lots of repeated values in a dataset. There can be no mode, one mode or multiple modes.
#
# ![image.png](attachment:image.png)

# %%
# calculating mode of the above dataset
import numpy as np
import statistics as st
data=np.array([150,160,160,170,155,180,175])
mode = st.mode(data)
print("The mode of the data point is",mode)
# Out:
# The mode of the data point is 160

# %% [markdown]
# # Median
#
# The middle number found by ordering all the data points and picking out the one in the middle (or if there are two middle numbers, taking the mean of those two numbers).
#
# Finding the median: The median is the middle point in a dataset - half of the datapoints are smaller than the median and half of the data points are larger.
#
# To calculate the median:
# 1. Arrange the data points from smallest to largest.
# 2. If the number of data points is odd, the median is the middle data points in the list.
# 3. If the number of data point is even , then the median is the average of the two middle data points in the list.
#
# ![image-3.png](attachment:image-3.png)
#
# Q.1 Find the median of this data: 150,160,160,170,155,180,175
#
# Q.2. Find the median of this data: 150,160,160,170,190,155,180,175
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)
